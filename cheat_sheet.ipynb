# %% [markdown]
# # ✅ Docker CLI Cheat Sheet [Management] 👇

# %% [markdown]
# ```bash
# docker info                                      :: Display system information
# docker version                                   :: Display the systems version
# docker login                                     :: Log in to docker registry
# ```

# %% [markdown]
# # ✅ Docker CLI Cheat Sheet [Running and stopping] 👇

# %% [markdown]
# ```bash
# docker pull [imageName]                          :: Pull an image from a registry
# docker run [imageName]                           :: Run a container
# docker run -d [imageName]                        :: Detached mode
# docker start [containerName]                     :: Start stopped container
# docker ps                                        :: list running containers
# docker ps -a                                     :: List all containers both running and stopped
# docker stop [containerName]                      :: Stop containers
# docker kill [containerName]                      :: Kill containers
# docker image inspect [imageName]                 :: Get image details information
# docker restart [containerName]                   :: Re-start containers ~
# docker rm [containerName]                        :: Remove stopped containers ~
# docker logs [containerName]                      :: View container output logs ~
# ```

# %% [markdown]
# # ✅ Docker CLI Cheat Sheet [Volumes] 👇

# %% [markdown]
# ```bash
# docker volume create [volumeName]                :: Create a new volume
# docker volume ls                                 :: List all volumes
# docker volume inspect [volumeName]               :: Display the volume information details
# docker volume rm [volumeName]                    :: Delete a volume
# docker volume prune                              :: Delete all the volumes that are not mounted
# ```

# %% [markdown]
# # ✅ Mapping a volume 👇

# %% [markdown]
# ```bash
# docker volume create myvol                                      :: Create a volume
# docker volume inspect myvol                                     :: Inspect the volume
# docker volume ls                                                :: List the volumes
# docker run -d --name myContainer -v myvol:/app nginx:latest     :: Run a container with a volume
# docker exec -it myContainer bash                                :: Connect to instance
#
# # Creating files using nano
# apt-get update
# apt-get install nano
# ```

# %% [markdown]
# # ✅ Mapping to a local folder 👇

# %% [markdown]
# ```bash
# # Run a container with a volume
# docker run -d --name myContainer -v /home/rakib/Desktop/dev/Learn_Docker/ nginx:latest
#
# # Inspect the container
# docker inspect myContainer
#
# ```

# %% [markdown]
# # ✅ YAML for Docker and Kubernates 👇

# %% [markdown]
# ```bash
# # Comments Example
#
# key: value
# another_key: Another value
# a_number_value: 10
#
# # Nesting uses indentation. 2 space indent is preferred (not required)
# a_nested_map:
#     key: value
#     another_key: Another Value
#     another_nested_map:
#         hello: Hello
#
# # Sequences (equivalent to lists or arrays) look like this
# # (NB: '-' counts as indentation):
# a_sequence:
#     - Item 1
#     - Item 2
#     - Item 3
#
# # Json style indentaiton example (Not Convenient for YAML)
# json_map: {"key": "value"}
# json_sequence: [3, 2, 1, "Hello"]
# ```

# %% [markdown]
# # ✅ Docker Compose Use Cases 👇
# ```bash
# 1. Define and run multi-containers application
# 2. Defined using an YAML
# 3. Run using docker cli with the compose plugin [ Docker Compose ]
# ```

# %% [markdown]
# # ✅ Docker Compose YAML Example 👇

# %% [markdown]
# ```bash
# version: '3.9'
#
# services:
#     webapi1:
#         image: acadeny.azurecr.io/webapi1
#         ports:
#             - '8081:80'
#         restart: always
#
#     webapi2:
#         image: acadeny.azurecr.io/webapi2
#         ports:
#             - '8082:80'
#         restart: always
#
#     apigateway:
#         image: academy.azurec.io/apigateway
#         ports:
#             - '80:80'
#         restart: always
# ```

# %% [markdown]
# # ✅ Docker Compose Cheat Sheet 👇

# %% [markdown]
# ```bash
# docker compose build                                            :: Build the images
# docker compose start                                            :: Start the containers
# docker compose stop                                             :: Stop the containers
# docker compose up -d                                            :: Build and start
# docker compose ps                                               :: Lists of running containers
# docker compose rm                                               :: Remove from memory
# docker compose down                                             :: Stop and remove
# docker compose logs                                             :: Get the logs
# docker compose exec [containerName] bash                        :: Run a command in a container
# ```

# %% [markdown]
# # ✅ Docker Compose Version 2 (New Commands) Cheat Sheet 👇

# %% [markdown]
# ```bash
# docker compose --project-name test1 up -d                       :: Run an instace as a project
# docker compose -p test2 up -d                                   :: Shortcut
# docker compose ls                                               :: List running projects
# docker compose cp [containerID]: [SRC_PATH] [DEST_PATH]         :: Copy files from the container
# docker compose cp [SRC_PATH] [containerID]: [DEST_PATH]         :: Copy files to the container
# ```

# %% [markdown]
# # ✅ Docker Compose YAML Example 👇

# %% [markdown]
# ```bash
# # docker-compose.yaml
# services:
#     web-fe:
#         build: .
#         command: python main.py
#         ports:
#           - 5000:5000
#
#     redis:
#         image: "redis.alpine"
#         ports:
#             - 6379
# ```

# %% [markdown]
# # ✅ Docker Compose Example 👇
# ```bash
# docker compose build                    :: Build the app
# docker compose up -d                    :: Build + Run the app
# docker compose ps                       :: Lists the containers
# docker ps                               :: List of running docker containers
# docker compose logs -f web-fe           :: Look at the DB container logs
# docker compose ls                       :: Lists the currently running projects
#
# ```

# %% [markdown]
# # ✅ Publish Docker Hub 👇
# ```bash
# docker login -u <userName> -p <password>                    :: Log in to Docker Hub
# docker tag my_image_name rakib72642/my_image_name:latest    :: Tag the image previously built
# docker push rakib72642/my_image_name:latest                 :: Push the image
# docke pull rakib72642/my_image_name:latest                  :: Pull the image
# ```

# %% [markdown]
# # ✅ Kubernetes 👇
# ```bash
# => A context is a group of access parameters to a k8s cluster
# => Contains a kubernetes [Cluster, a User and a namespace]
# => The curreent context is the cluster that is currently the default for kubectl
#    => All kubectl commands run against that cluster
# ```

# %% [markdown]
# # ✅ Kubernetes CLI and Contexts 👇
# ```bash
# kubectl cluster-info                                        :: Shows Kuberneted datails
# kubectl config current-context                              :: Get the current Context
# kubectl config get-contexts                                 :: Lists all contexts
# kubectl config use-context [contextName]                    :: Set the current context
# kubectl config rename-context [oldName] [newName]           :: Rename the context
# kubectl config delete-context [contextName]                 :: Delete a context from the config file
#
# ```
